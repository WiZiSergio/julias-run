# %% [markdown]
# # 🎮 POO en Python: de 0 a juego
#
# ---
#
# > **¡Bienvenido/a al mundo de la Programación Orientada a Objetos!**
# > Este cuaderno te preparará para entender el código de **Julia's Run** en ~45-60 minutos.
#
# ---
#
# ## 🎯 Objetivos de Aprendizaje
#
# Al completar este notebook, serás capaz de:
#
# ✅ **Crear clases** y distinguir entre clase y objeto
# ✅ **Usar atributos** para guardar el estado
# ✅ **Definir métodos** para el comportamiento
# ✅ **Entender `self`** y por qué es importante
# ✅ **Aplicar encapsulación** básica
# ✅ **Conectar conceptos** con el código del juego
#
# ---
#
# ## 🕐 Duración Estimada
# - **Lectura y teoría**: 15 min
# - **Ejercicios prácticos**: 30 min
# - **Quiz y reflexión**: 15 min
#
# ---
#
# ## 📋 Prerrequisitos
# - ✅ Variables y tipos básicos
# - ✅ Funciones
# - ✅ Listas y diccionarios
# - ✅ Bucles y condicionales
#
# ¿Listo/a? ¡Empezamos! 🚀

# %% [markdown]
# ---
#
# # 🤔 ¿Por qué POO?
#
# Imagina que tienes que programar un juego. **Sin POO**, tendrías algo así:

# %%
# ❌ Código sin POO - ¡Un desastre!
jugador_x = 100
jugador_y = 200
jugador_vidas = 3
jugador_puntos = 0

enemigo1_x = 50
enemigo1_y = 50
enemigo1_vidas = 2

enemigo2_x = 150
enemigo2_y = 75
enemigo2_vidas = 2

def mover_jugador(direccion):
    global jugador_x, jugador_y
    if direccion == "izquierda":
        jugador_x -= 10
    # ... más código repetitivo

def mover_enemigo1(direccion):
    global enemigo1_x, enemigo1_y
    # ... código casi idéntico al anterior

def mover_enemigo2(direccion):
    global enemigo2_x, enemigo2_y
    # ... ¡más código repetido!

print("😱 Imagina tener 20 enemigos... ¡Sería un caos!")
# Out:
# 😱 Imagina tener 20 enemigos... ¡Sería un caos!

# %% [markdown]
# ## ✨ La POO nos salva porque permite:
#
# ### 🗂️ **Organizar código**
# - Cada "cosa" (jugador, enemigo) tiene su lugar
#
# ### 🏗️ **Modelar "cosas" del mundo real**
# - Un jugador **es** algo que tiene posición, vidas, y puede moverse
#
# ### ♻️ **Reutilizar código**
# - Una vez que defines "Enemigo", puedes crear 100 sin repetir código
#
# ### 🔧 **Mantener y cambiar fácilmente**
# - Si cambias cómo se mueve un enemigo, ¡cambia para todos automáticamente!
#
# ---
#
# **¿Curioso/a por ver cómo?** ¡Sigamos! 👇

# %% [markdown]
# ---
#
# # 🏗️ Tu Primera Clase: Jugador
#
# ¡Hora de crear tu primera clase! Una **clase** es como un **molde para galletas** 🍪 - defines la forma una vez, y puedes hacer todas las galletas que quieras.
#
# ## 🎭 De problema real a solución POO
#
# **Problema**: Necesitamos muchos personajes en nuestro juego
# **Solución**: ¡Crear una clase `Jugador`!

# %%
# ✨ ¡Nuestra primera clase!
class Jugador:
    def __init__(self, nombre):
        """
        Constructor: se ejecuta cuando creamos un nuevo jugador
        """
        print(f"🎮 ¡Creando jugador {nombre}!")
        
        # 📦 ATRIBUTOS: características del jugador
        self.nombre = nombre
        self.vidas = 3
        self.puntos = 0
        self.x = 100  # posición horizontal
        self.y = 200  # posición vertical
        
        print(f"✅ {self.nombre} está listo con {self.vidas} vidas")
    
    # ⚡ MÉTODOS: acciones que puede hacer el jugador
    def mover(self, direccion):
        """Mover el jugador en una dirección"""
        if direccion == "izquierda":
            self.x -= 10
            print(f"👈 {self.nombre} se movió a la izquierda (x={self.x})")
        elif direccion == "derecha":
            self.x += 10
            print(f"👉 {self.nombre} se movió a la derecha (x={self.x})")
        elif direccion == "arriba":
            self.y -= 10
            print(f"👆 {self.nombre} subió (y={self.y})")
        elif direccion == "abajo":
            self.y += 10
            print(f"👇 {self.nombre} bajó (y={self.y})")
    
    def puntuar(self, puntos):
        """Añadir puntos al jugador"""
        self.puntos += puntos
        print(f"🌟 ¡{self.nombre} ganó {puntos} puntos! Total: {self.puntos}")
    
    def herir(self):
        """Quitar una vida al jugador"""
        if self.vidas > 0:
            self.vidas -= 1
            print(f"💔 ¡{self.nombre} perdió una vida! Quedan: {self.vidas}")
            if self.vidas == 0:
                print(f"💀 ¡{self.nombre} ha perdido el juego!")
        return self.vidas > 0  # True si sigue vivo

print("🎯 ¡Clase Jugador creada! Ahora vamos a usarla...")
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ## 🎪 ¡Hora del espectáculo! Creemos personajes
#
# Ejecuta la celda de arriba y luego esta:

# %%
# 🎭 Creando OBJETOS desde la clase (como galletas del molde)
print("=== 🏭 FÁBRICA DE JUGADORES ===")

# Crear dos jugadores diferentes
julia = Jugador("Julia")
cale = Jugador("Cale")

print("\n=== 🎮 ESTADO INICIAL ===")
print(f"📊 {julia.nombre}: {julia.vidas} vidas, {julia.puntos} puntos, posición ({julia.x}, {julia.y})")
print(f"📊 {cale.nombre}: {cale.vidas} vidas, {cale.puntos} puntos, posición ({cale.x}, {cale.y})")

print("\n💡 ¡Fíjate! Son dos OBJETOS diferentes con el mismo 'molde' (clase)")
print(f"🔍 julia es de tipo: {type(julia)}")
print(f"🔍 cale es de tipo: {type(cale)}")
# Out:
# === 🏭 FÁBRICA DE JUGADORES ===
# 🎮 ¡Creando jugador Julia!
# ✅ Julia está listo con 3 vidas
# 🎮 ¡Creando jugador Cale!
# ✅ Cale está listo con 3 vidas
#
# === 🎮 ESTADO INICIAL ===
# 📊 Julia: 3 vidas, 0 puntos, posición (100, 200)
# 📊 Cale: 3 vidas, 0 puntos, posición (100, 200)
#
# 💡 ¡Fíjate! Son dos OBJETOS diferentes con el mismo 'molde' (clase)
# 🔍 julia es de tipo: <class '__main__.Jugador'>
# 🔍 cale es de tipo: <class '__main__.Jugador'>

# %% [markdown]
# ## 🎲 Mini-Ejercicio: ¡Simula 5 eventos de juego!
#
# **Tu misión**: Haz que Julia y Cale vivan una pequeña aventura de 5 eventos.
#
# **Eventos disponibles**:
# - `.mover("direccion")` → izquierda, derecha, arriba, abajo
# - `.puntuar(cantidad)` → cualquier número
# - `.herir()` → quita una vida
#
# **¡Sé creativo/a!** Cuenta una historia con tus compañeros de clase... 🎭
#
# 💡 **Ideas**: ¿Quién llega primero al tesoro? ¿Quién evita más obstáculos? ¿Quién consigue más puntos?

# %%
# 🎮 ¡TU TURNO! Programa aquí tu aventura de 5 eventos
print("=== 🏁 ¡COMIENZA LA AVENTURA! ===")

# Ejemplos para inspirarte (¡pero crea la tuya!):
# julia.mover("derecha")
# cale.puntuar(15) 
# julia.herir()
# cale.mover("arriba")
# julia.puntuar(20)

# ✏️ Escribe tu código aquí:
# ¿Quizás Wizi vs Dani? ¿O Roxi vs Miguel? ¡Crea tu propia historia!

wizi = Jugador("Wizi")
dani = Jugador("Dani")
wizi.vidas = 5
dani.vidas = 4
wizi.mover("derecha")
dani.puntuar(15)
wizi.herir()
dani.mover("arriba")
wizi.puntuar(20)




print("\n=== 📊 ESTADO FINAL ===")
print(f"📊 {wizi.nombre}: {wizi.vidas} vidas, {wizi.puntos} puntos, posición ({wizi.x}, {wizi.y})")
print(f"📊 {dani.nombre}: {dani.vidas} vidas, {dani.puntos} puntos, posición ({dani.x}, {dani.y})")

print("\n🤔 ¿Notaste cómo cada objeto mantiene su propio estado?")
print("🎓 ¡Esto es la base de la POO! Cada objeto es independiente.")
# Out:
# === 🏁 ¡COMIENZA LA AVENTURA! ===
# 🎮 ¡Creando jugador Wizi!
# ✅ Wizi está listo con 3 vidas
# 🎮 ¡Creando jugador Dani!
# ✅ Dani está listo con 3 vidas
# 👉 Wizi se movió a la derecha (x=110)
# 🌟 ¡Dani ganó 15 puntos! Total: 15
# 💔 ¡Wizi perdió una vida! Quedan: 4
# 👆 Dani subió (y=190)
# 🌟 ¡Wizi ganó 20 puntos! Total: 20
#
# === 📊 ESTADO FINAL ===
# 📊 Wizi: 4 vidas, 20 puntos, posición (110, 200)
# 📊 Dani: 4 vidas, 15 puntos, posición (100, 190)
#
# 🤔 ¿Notaste cómo cada objeto mantiene su propio estado?
# 🎓 ¡Esto es la base de la POO! Cada objeto es independiente.

# %% [markdown]
# ---
#
# # 🕵️ El Misterio de `self` - ¡Resuelto!
#
# **Pregunta del millón**: ¿Por qué todos los métodos empiezan con `self`? 🤔
#
# ## 🎭 Imaginemos una conversación...
#
# **Roxi**: "¡Oye, muévete a la derecha!"
# **¿Quién se mueve?** ¿Roxi? ¿Marcus? ¿Rubén?
#
# **En POO es igual**: Cuando llamas `mover("derecha")`, ¿quién se mueve?
#
# `self` = **"YO, el objeto que está ejecutando este método"**

# %%
# 🔍 ¡Experimento para entender self!
print("=== 🧪 EXPERIMENTO SELF ===")

# Creamos varios estudiantes
miguel = Jugador("Miguel")
marcus = Jugador("Marcus")
dani = Jugador("Dani")

print("\n=== 🎯 POSICIONES INICIALES ===")
print(f"Miguel está en x={miguel.x}")
print(f"Marcus está en x={marcus.x}")  
print(f"Dani está en x={dani.x}")

print("\n=== 🏃 ¡CADA UNO SE MUEVE INDEPENDIENTEMENTE! ===")

# Cada uno se mueve - ¡observa los mensajes!
miguel.mover("derecha")  # self será miguel
marcus.mover("izquierda")   # self será marcus  
dani.mover("derecha")    # self será dani

print("\n=== 📍 POSICIONES FINALES ===")
print(f"Miguel terminó en x={miguel.x}")
print(f"Marcus terminó en x={marcus.x}")
print(f"Dani terminó en x={dani.x}")

print("\n💡 ¡Fíjate! Cada objeto modificó SU PROPIO estado, no el de los otros")
print("🎯 ESO es lo que hace 'self': indica 'mi propio estado'")
# Out:
# === 🧪 EXPERIMENTO SELF ===
# 🎮 ¡Creando jugador Miguel!
# ✅ Miguel está listo con 3 vidas
# 🎮 ¡Creando jugador Marcus!
# ✅ Marcus está listo con 3 vidas
# 🎮 ¡Creando jugador Dani!
# ✅ Dani está listo con 3 vidas
#
# === 🎯 POSICIONES INICIALES ===
# Miguel está en x=100
# Marcus está en x=100
# Dani está en x=100
#
# === 🏃 ¡CADA UNO SE MUEVE INDEPENDIENTEMENTE! ===
# 👉 Miguel se movió a la derecha (x=110)
# 👈 Marcus se movió a la izquierda (x=90)
# 👉 Dani se movió a la derecha (x=110)
#
# === 📍 POSICIONES FINALES ===
# Miguel terminó en x=110
# Marcus terminó en x=90
# Dani terminó en x=110
#
# 💡 ¡Fíjate! Cada objeto modificó SU PROPIO estado, no el de los otros
# 🎯 ESO es lo que hace 'self': indica 'mi propio estado'

# %% [markdown]
# ## 🎮 Mini-Ejercicio: ¡Añade velocidad!
#
# **Tu misión**: Mejora la clase `Jugador` añadiendo:
# - Un atributo `velocidad` (por defecto 10)
# - Un método `acelerar(factor)` que multiplique la velocidad
# - Modifica `mover()` para usar la velocidad actual
#
# **¡Piensa!** ¿Dónde va cada cosa?

# %%
# 🚀 ¡Mejoremos la clase Jugador!
class JugadorMejorado:
    def __init__(self, nombre):
        print(f"🎮 ¡Creando jugador mejorado {nombre}!")
        
        # Atributos existentes
        self.nombre = nombre
        self.vidas = 3
        self.puntos = 0
        self.x = 100
        self.y = 200
        
        # 🆕 ¡NUEVO! Atributo velocidad
        self.velocidad = 30  # píxeles por movimiento
        
        print(f"✅ {self.nombre} está listo con velocidad {self.velocidad}")
    
    def mover(self, direccion):
        """Mover usando la velocidad actual"""
        if direccion == "izquierda":
            self.x -= self.velocidad  # ¡Usa self.velocidad!
            print(f"👈 {self.nombre} se movió {self.velocidad} píxeles a la izquierda (x={self.x})")
        elif direccion == "derecha":
            self.x += self.velocidad
            print(f"👉 {self.nombre} se movió {self.velocidad} píxeles a la derecha (x={self.x})")
        # ... (arriba y abajo igual)
    
    def acelerar(self, factor):
        """🚀 Acelerar el jugador"""
        self.velocidad *= factor
        print(f"🏃‍♀️ ¡{self.nombre} ahora va a velocidad {self.velocidad}!")
    
    def puntuar(self, puntos):
        self.puntos += puntos
        print(f"🌟 ¡{self.nombre} ganó {puntos} puntos! Total: {self.puntos}")
    
    def herir(self):
        if self.vidas > 0:
            self.vidas -= 1
            print(f"💔 ¡{self.nombre} perdió una vida! Quedan: {self.vidas}")
        return self.vidas > 0

print("🎯 ¡Clase mejorada creada!")
# Out:
# 🎯 ¡Clase mejorada creada!

# %%
# 🏁 ¡Carrera de velocidad entre compañeros!
print("=== 🏁 CARRERA DE VELOCIDAD ===")

# Creamos corredores de la clase
presi = JugadorMejorado("Presi")
ramazan = JugadorMejorado("Ramazan") 
wizi = JugadorMejorado("Wizi")
cale = JugadorMejorado("Cale")

print("\n=== 🚀 ¡MODIFICAMOS VELOCIDADES! ===")
presi.acelerar(2)        # Presi va 2x más rápido
ramazan.acelerar(1.5)    # Ramazan 1.5x más rápido 
cale.acelerar(0.5)      # Cale va más lento 
# Wizi mantiene velocidad normal

print("\n=== 🏃 ¡A CORRER! ===")
print("🏁 Cada uno da 3 pasos a la derecha...")

for paso in range(1, 4):
    print(f"\n--- Paso {paso} ---")
    presi.mover("derecha")
    ramazan.mover("derecha")
    wizi.mover("derecha")
    cale.mover("derecha")

print("\n=== 🏆 RESULTADOS FINALES ===")
print(f"🥇 Presi: posición x={presi.x} (velocidad {presi.velocidad})")
print(f"🥈 Ramazan: posición x={ramazan.x} (velocidad {ramazan.velocidad})")
print(f"🥉 Wizi: posición x={wizi.x} (velocidad {wizi.velocidad})")
print(f"🏅 Cale: posición x={cale.x} (velocidad {cale.velocidad})")

print("\n💡 ¡Cada objeto mantiene SU PROPIA velocidad!")
print("🎯 Esto es encapsulación: cada objeto controla su propio estado")
# Out:
# === 🏁 CARRERA DE VELOCIDAD ===
# 🎮 ¡Creando jugador mejorado Presi!
# ✅ Presi está listo con velocidad 30
# 🎮 ¡Creando jugador mejorado Ramazan!
# ✅ Ramazan está listo con velocidad 30
# 🎮 ¡Creando jugador mejorado Wizi!
# ✅ Wizi está listo con velocidad 30
# 🎮 ¡Creando jugador mejorado Cale!
# ✅ Cale está listo con velocidad 30
#
# === 🚀 ¡MODIFICAMOS VELOCIDADES! ===
# 🏃‍♀️ ¡Presi ahora va a velocidad 60!
# 🏃‍♀️ ¡Ramazan ahora va a velocidad 45.0!
# 🏃‍♀️ ¡Cale ahora va a velocidad 15.0!
#
# === 🏃 ¡A CORRER! ===
# 🏁 Cada uno da 3 pasos a la derecha...
#
# --- Paso 1 ---
# 👉 Presi se movió 60 píxeles a la derecha (x=160)
# 👉 Ramazan se movió 45.0 píxeles a la derecha (x=145.0)
# 👉 Wizi se movió 30 píxeles a la derecha (x=130)
# 👉 Cale se movió 15.0 píxeles a la derecha (x=115.0)
#
# --- Paso 2 ---
# 👉 Presi se movió 60 píxeles a la derecha (x=220)
# 👉 Ramazan se movió 45.0 píxeles a la derecha (x=190.0)
# 👉 Wizi se movió 30 píxeles a la derecha (x=160)
# ...

# %% [markdown]
# ---
#
# # 🔫 Composición Simple: ¡Objetos que usan otros objetos!
#
# **Nuevo reto**: Nuestros jugadores necesitan **cuchillos** para defenderse.
#
# ¿Cómo modelamos esto? 🤔
#
# ## 🧩 Solución: ¡Una clase usa otra clase!
#
# - **Jugador** → puede crear y usar **Cuchillos**
# - **Cuchillo** → tiene su propia lógica (dirección, velocidad)
#
# **Esto es COMPOSICIÓN**: Un objeto "tiene" otros objetos

# %%
# 🔪 ¡Creemos la clase Cuchillo!
class Cuchillo:
    def __init__(self, x, y, direccion):
        """Un cuchillo tiene posición y dirección"""
        self.x = x
        self.y = y
        self.direccion = direccion
        self.velocidad = 15  # Los cuchillos van rápido
        self.activo = True   # ¿Sigue volando?
        
        print(f"🔪 ¡Cuchillo lanzado desde ({x}, {y}) hacia {direccion}!")
    
    def update(self):
        """Mover el cuchillo según su dirección"""
        if self.activo:
            if self.direccion == "arriba":
                self.y -= self.velocidad
            elif self.direccion == "abajo":  
                self.y += self.velocidad
            elif self.direccion == "izquierda":
                self.x -= self.velocidad
            elif self.direccion == "derecha":
                self.x += self.velocidad
            
            # ¿Se salió de la pantalla?
            if self.y < 0 or self.y > 400 or self.x < 0 or self.x > 800:
                self.activo = False
                print(f"💨 Cuchillo salió de pantalla en ({self.x}, {self.y})")

# 🎮 ¡Jugador que puede lanzar cuchillos!
class JugadorConCuchillos:
    def __init__(self, nombre):
        self.nombre = nombre
        self.x = 100
        self.y = 200
        self.cuchillos = []  # 📦 Lista de cuchillos lanzados
        self.enfriamiento = 0  # Contador para evitar spam
        
        print(f"🎮 {self.nombre} está listo para lanzar cuchillos!")
    
    def lanzar_cuchillo(self, direccion):
        """🔫 Lanzar un cuchillo si no hay enfriamiento"""
        if self.enfriamiento <= 0:
            # Crear un nuevo cuchillo en mi posición
            nuevo_cuchillo = Cuchillo(self.x, self.y, direccion)
            self.cuchillos.append(nuevo_cuchillo)
            self.enfriamiento = 3  # 3 turnos de enfriamiento
            print(f"🎯 {self.nombre} lanzó un cuchillo hacia {direccion}")
        else:
            print(f"⏰ {self.nombre} debe esperar {self.enfriamiento} turnos")
    
    def update(self):
        """Actualizar enfriamiento y todos los cuchillos"""
        # Reducir enfriamiento
        if self.enfriamiento > 0:
            self.enfriamiento -= 1
        
        # Actualizar todos los cuchillos
        for cuchillo in self.cuchillos:
            cuchillo.update()
        
        # Limpiar cuchillos inactivos
        cuchillos_activos = [c for c in self.cuchillos if c.activo]
        eliminados = len(self.cuchillos) - len(cuchillos_activos)
        self.cuchillos = cuchillos_activos
        
        if eliminados > 0:
            print(f"🧹 {self.nombre} limpió {eliminados} cuchillos inactivos")

print("🎯 ¡Clases de combate creadas!")
# Out:
# 🎯 ¡Clases de combate creadas!

# %%
# ⚔️ ¡Duelo de cuchillos entre Rubén y David!
print("=== ⚔️ DUELO DE CUCHILLOS ===")

ruben = JugadorConCuchillos("Rubén")
david = JugadorConCuchillos("David")
julia = JugadorConCuchillos("Julia")

print("\n=== 🎯 RONDA 1: LANZAMIENTOS ===")
ruben.lanzar_cuchillo("arriba")
david.lanzar_cuchillo("derecha")
ruben.lanzar_cuchillo("izquierda")  # ¿Podrá lanzar tan rápido?
julia.lanzar_cuchillo("abajo")

print(f"\n📊 Rubén tiene {len(ruben.cuchillos)} cuchillos volando")
print(f"📊 David tiene {len(david.cuchillos)} cuchillos volando")
print(f"📊 Julia tiene {len(julia.cuchillos)} cuchillos volando")

print("\n=== ⏰ SIMULANDO 5 TURNOS ===")
for turno in range(1, 6):
    print(f"\n--- Turno {turno} ---")
    
    # Actualizar ambos jugadores
    ruben.update()
    david.update()
    julia.update()
    
    # Intentar lanzar más cuchillos
    if turno == 2:
        david.lanzar_cuchillo("arriba")
    if turno == 4:
        ruben.lanzar_cuchillo("derecha")
        david.lanzar_cuchillo("izquierda")
    if turno == 5:
        julia.lanzar_cuchillo("abajo") 
    
    print(f"📊 Estado turno {turno}:")
    print(f"   Rubén: {len(ruben.cuchillos)} cuchillos, enfriamiento: {ruben.enfriamiento}")
    print(f"   David: {len(david.cuchillos)} cuchillos, enfriamiento: {david.enfriamiento}")
    print(f"   Julia: {len(julia.cuchillos)} cuchillos, enfriamiento: {julia.enfriamiento}")

print("\n💡 ¡Fíjate los conceptos de POO!")
print("🔸 COMPOSICIÓN: Jugador 'tiene' una lista de Cuchillos")
print("🔸 RESPONSABILIDADES: Cada clase sabe qué hacer")
print("🔸 ESTADO: Cada objeto mantiene sus propios datos")
# Out:
# === ⚔️ DUELO DE CUCHILLOS ===
# 🎮 Rubén está listo para lanzar cuchillos!
# 🎮 David está listo para lanzar cuchillos!
# 🎮 Julia está listo para lanzar cuchillos!
#
# === 🎯 RONDA 1: LANZAMIENTOS ===
# 🔪 ¡Cuchillo lanzado desde (100, 200) hacia arriba!
# 🎯 Rubén lanzó un cuchillo hacia arriba
# 🔪 ¡Cuchillo lanzado desde (100, 200) hacia derecha!
# 🎯 David lanzó un cuchillo hacia derecha
# ⏰ Rubén debe esperar 3 turnos
# 🔪 ¡Cuchillo lanzado desde (100, 200) hacia abajo!
# 🎯 Julia lanzó un cuchillo hacia abajo
#
# 📊 Rubén tiene 1 cuchillos volando
# 📊 David tiene 1 cuchillos volando
# 📊 Julia tiene 1 cuchillos volando
#
# === ⏰ SIMULANDO 5 TURNOS ===
#
# --- Turno 1 ---
# 📊 Estado turno 1:
#    Rubén: 1 cuchillos, enfriamiento: 2
#    David: 1 cuchillos, enfriamiento: 2
#    Julia: 1 cuchillos, enfriamiento: 2
#
# --- Turno 2 ---
# ⏰ David debe esperar 1 turnos
# 📊 Estado turno 2:
#    Rubén: 1 cuchillos, enfriamiento: 1
#    David: 1 cuchillos, enfriamiento: 1
# ...

# %% [markdown]
# ---
#
# # 📁 Modularidad: ¡Orden en el código!
#
# **Problema**: Si seguimos añadiendo clases, ¡el archivo se hará gigantesco! 😱
#
# **Solución**: Separar en archivos según su propósito
#
# ## 🗂️ Organización típica en un juego:
#
# ```
# mi_juego/
# ├── entities.py     # 👾 Jugador, Obstáculo, Cuchillo, PowerUp
# ├── abilities.py    # ⚡ Efectos, Cooldowns, Combos
# ├── game_states.py  # 🎯 Menú, Jugando, Pausa, GameOver
# ├── settings.py     # ⚙️ Constantes, configuración
# └── main.py         # 🎮 Game loop principal
# ```
#
# ### 💡 ¿Por qué separar?
#
# - **🔍 Fácil de encontrar**: "Las clases de personajes están en entities.py"
# - **👥 Trabajo en equipo**: Cada persona puede trabajar en un archivo
# - **🔧 Mantenimiento**: Cambiar un power-up no toca el código del jugador
# - **♻️ Reutilización**: Puedes usar las clases en otros proyectos

# %% [markdown]
# ---
#
# # 🌉 Puente a Julia's Run: ¡Conecta lo aprendido!
#
# **¡Ya sabes POO!** 🎉 Ahora verás estos conceptos en el juego real.
#
# ## 🔗 Tabla de Analogías
#
# | 🔬 **En el notebook** | 🎮 **En Julia's Run** | 📂 **Archivo** |
# |----------------------|----------------------|----------------|
# | `Jugador(nombre)` | `Player()` | `src/entities.py` |
# | `Cuchillo(x, y, dir)` | `Knife(x, y)` | `src/entities.py` |
# | `lista de cuchillos` | `obstacles, knives` | `src/main.py` |
# | `método update()` | `ciclo de juego` | `src/main.py` |
# | `enfriamiento` | `CooldownTimer` | `src/abilities.py` |
# | `JugadorConCuchillos` | `Player + abilities` | `src/entities.py + abilities.py` |
#
# ## 🕵️ ¿Qué buscar en el código del juego?
#
# ### 📄 **src/entities.py** - ¡Las clases principales!
# ```python
# class Player:          # Como nuestro Jugador
# class Obstacle:        # Enemigos que caen
# class Knife:           # Como nuestro Cuchillo
# class PowerUp:         # Items especiales
# ```
#
# ### 📄 **src/main.py** - ¡El director de orquesta!
# ```python
# # Listas de objetos (como nuestras listas)
# obstacles = []
# knives = []
#
# # Ciclo del juego (como nuestro .update())
# while running:
#     # Actualizar todos los objetos
#     player.update()
#     for obstacle in obstacles:
#         obstacle.update()
# ```
#
# ### 📄 **src/game_states.py** - ¡Los menús!
# ```python
# # Estados del juego usando POO
# class MenuState:
# class PlayingState:
# class GameOverState:
# ```

# %% [markdown]
# ---
#
# # 🧠 Checkpoint: Quiz POO
#
# **¡Hora de comprobar lo aprendido!** 🎯
#
# ### 🤔 Pregunta 1
# ¿Cuál es la diferencia entre **clase** y **objeto**?
#
# ### 🤔 Pregunta 2
# ¿Para qué sirve `self` en los métodos?
#
# ### 🤔 Pregunta 3
# Si tienes `roxi = Jugador("Roxi")` y llamas `roxi.mover("izquierda")`, ¿qué objeto se mueve y por qué?
#
# ### 🤔 Pregunta 4
# ¿Qué es composición? Da un ejemplo del notebook.
#
# ### 🤔 Pregunta 5
# ¿Por qué es buena idea separar las clases en archivos diferentes?
#
# ---
#
# **🤫 ¡Respuestas en la siguiente celda!** (Intenta responder primero)

# %%
# 📝 SOLUCIONES DEL QUIZ
print("=== 🎯 RESPUESTAS CORRECTAS ===")

print("""
🤔 Pregunta 1: ¿Diferencia entre clase y objeto?
✅ CLASE = Molde/plantilla (como 'Jugador')
   OBJETO = Instancia específica (como 'roxi = Jugador("Roxi")')
   Una clase puede crear muchos objetos.

🤔 Pregunta 2: ¿Para qué sirve 'self'?
✅ 'self' es la referencia al objeto actual que ejecuta el método.
   Le dice al método "trabaja con MIS datos, no con los de otros objetos".

🤔 Pregunta 3: ¿Qué objeto se mueve?
✅ Se mueve el objeto 'roxi' porque 'self' dentro del método mover()
   se refiere específicamente a ese objeto.

🤔 Pregunta 4: ¿Qué es composición?
✅ Un objeto "tiene" otros objetos dentro.
   Ejemplo: JugadorConCuchillos tiene una lista de objetos Cuchillo.

🤔 Pregunta 5: ¿Por qué separar en archivos?
✅ Organización, trabajo en equipo, mantenimiento más fácil,
   y reutilización de código.
""")

print("🎉 ¡Si entendiste la mayoría, estás listo/a para Julia's Run!")
print("🎮 ¡Hora de ver POO en acción en un juego real!")

# %% [markdown]
# ---
#
# # 🚀 Tarea Puente: ¡Tu misión final!
#
# **Antes de saltar al juego**, demuestra que dominas POO:
#
# ## 🎯 Implementa `EnemigoEspecial`
#
# Crea una clase que tenga:
# - **Atributo**: `armadura` (cantidad de hits que puede recibir)
# - **Método**: `update()` (se mueve automáticamente)
# - **Método**: `recibir_daño()` (reduce armadura)
#
# ### 💭 Reflexión (3 frases):
# Escribe cómo integrarías esta clase en Julia's Run:
# 1. ¿En qué archivo la pondrías?
# 2. ¿Cómo interactuaría con los cuchillos del jugador?
# 3. ¿Qué efectos visuales añadirías?
#
# ---
#
# ## 🎊 ¡Felicidades!
#
# Has completado tu introducción a POO. **Conceptos dominados**:
#
# ✅ **Clases y objetos** → Plantillas y ejemplares
# ✅ **Atributos y métodos** → Estado y comportamiento
# ✅ **`self`** → Referencia al objeto actual
# ✅ **Encapsulación** → Cada objeto controla su estado
# ✅ **Composición** → Objetos que contienen otros objetos
# ✅ **Modularidad** → Organización en archivos
#
# ## 🎮 Próximos Pasos
#
# 1. **🎯 Ejecuta el juego**: `make run` para ver POO en acción
# 2. **📖 Lee el código**: Empieza con `src/entities.py`
# 3. **🔍 Busca patrones**: ¿Dónde ves los conceptos del notebook?
# 4. **🚀 Mejora algo**: Añade tu primera feature al juego
#
# ---
#
# ### 📚 Nota Final
#
# > Este notebook acompaña al proyecto **Julia's Run** y está pensado como guía previa antes de leer el código del juego.
# >
# > ¡Ahora tienes las herramientas para entender y mejorar un juego real usando POO! 🎉
#
# **¡Que disfrutes programando!** 👩‍💻👨‍💻
